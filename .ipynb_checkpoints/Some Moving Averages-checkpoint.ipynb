# %%
import numpy as np 
import pandas as pd 
import yfinance as yf
import matplotlib.pyplot as plt

# ^GSPC is the symbol of S&P 500 in Yahoo! Finance
tickerData = yf.Ticker('^GSPC')

df = tickerData.history(period='1d', start='2010-1-1', end='2011-10-1')

df.head()

close = df['Close']

all_weekdays = pd.date_range(start='2010-1-1', end='2011-10-1', freq='B')

close = close.reindex(all_weekdays)

close = close.fillna(method='ffill')

print(all_weekdays)

close.describe()

plt.plot(close)
# Out:
# DatetimeIndex(['2010-01-01', '2010-01-04', '2010-01-05', '2010-01-06',
#                '2010-01-07', '2010-01-08', '2010-01-11', '2010-01-12',
#                '2010-01-13', '2010-01-14',
#                ...
#                '2011-09-19', '2011-09-20', '2011-09-21', '2011-09-22',
#                '2011-09-23', '2011-09-26', '2011-09-27', '2011-09-28',
#                '2011-09-29', '2011-09-30'],
#               dtype='datetime64[ns]', length=456, freq='B')

# %%
df['Weekavg'] = df.Close.rolling(7).mean()
df['Monthavg'] = df.Close.rolling(30).mean()

# %%
plt.figure(figsize=(15,10))
plt.grid(True)
plt.plot(df['Close'], label='S&P 500', color='k')
plt.plot(df['Weekavg'], label='7 day average', color='b')
plt.plot(df['Monthavg'], label='30 day average', color='m')
plt.legend(loc=2)

# %%
# Dow Jones Index
tickerData = yf.Ticker('^DJI')

df = tickerData.history(period='1d', start='2010-1-1', end='2011-10-1')

df.head()

close = df['Close']

all_weekdays = pd.date_range(start='2010-1-1', end='2011-10-1', freq='B')

close = close.reindex(all_weekdays)

close = close.fillna(method='ffill')

print(all_weekdays)

close.describe()

plt.plot(close)
# Out:
# DatetimeIndex(['2010-01-01', '2010-01-04', '2010-01-05', '2010-01-06',
#                '2010-01-07', '2010-01-08', '2010-01-11', '2010-01-12',
#                '2010-01-13', '2010-01-14',
#                ...
#                '2011-09-19', '2011-09-20', '2011-09-21', '2011-09-22',
#                '2011-09-23', '2011-09-26', '2011-09-27', '2011-09-28',
#                '2011-09-29', '2011-09-30'],
#               dtype='datetime64[ns]', length=456, freq='B')

# %%
df['Weekavg'] = df.Close.rolling(7).mean()
df['Monthavg'] = df.Close.rolling(30).mean()

# %%
plt.figure(figsize=(15,10))
plt.grid(True)
plt.plot(df['Close'], label='Dow Jones Average', color='k')
plt.plot(df['Weekavg'], label='7 day average', color='b')
plt.plot(df['Monthavg'], label='30 day average', color='m')
plt.legend(loc=2)

# %%
# NASDAQ
tickerData = yf.Ticker('^IXIC')

df = tickerData.history(period='1d', start='2005-1-1', end='2006-10-1')

df.head()

close = df['Close']

all_weekdays = pd.date_range(start='2005-1-1', end='2006-10-1', freq='B')

close = close.reindex(all_weekdays)

close = close.fillna(method='ffill')

print(all_weekdays)

close.describe()

plt.plot(close)
# Out:
# DatetimeIndex(['2005-01-03', '2005-01-04', '2005-01-05', '2005-01-06',
#                '2005-01-07', '2005-01-10', '2005-01-11', '2005-01-12',
#                '2005-01-13', '2005-01-14',
#                ...
#                '2006-09-18', '2006-09-19', '2006-09-20', '2006-09-21',
#                '2006-09-22', '2006-09-25', '2006-09-26', '2006-09-27',
#                '2006-09-28', '2006-09-29'],
#               dtype='datetime64[ns]', length=455, freq='B')

# %%
df['Weekavg'] = df.Close.rolling(7).mean()
df['Monthavg'] = df.Close.rolling(30).mean()

# %%
plt.figure(figsize=(15,10))
plt.grid(True)
plt.plot(df['Close'], label='Dow Jones Average', color='k')
plt.plot(df['Weekavg'], label='7 day average', color='b')
plt.plot(df['Monthavg'], label='30 day average', color='m')
plt.legend(loc=2)
