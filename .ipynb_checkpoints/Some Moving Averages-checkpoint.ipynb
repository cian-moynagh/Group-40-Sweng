# %%
import numpy as np 
import pandas as pd 
import yfinance as yf
import matplotlib.pyplot as plt

# this function takes a data frame as a parameter and plots the 7 day rolling mean,
# the 30 day rolling mean and the actual value for the Closing value 

def moving_average(time_series):
    
    # getting the moving average
    df['Weekavg'] = df.Close.rolling(7).mean()
    df['Monthavg'] = df.Close.rolling(30).mean()
    
    # the plot itself
    plt.figure(figsize=(15,10))
    plt.grid(True)
    plt.plot(df['Close'], label='The Closing Value', color='k')
    plt.plot(df['Weekavg'], label='7 day average', color='b')
    plt.plot(df['Monthavg'], label='30 day average', color='m')
    plt.legend(loc=2)

# %%
# ^GSPC is the symbol of S&P 500 in Yahoo! Finance
tickerData = yf.Ticker('^GSPC')

df = tickerData.history(period='1d', start='2010-1-1', end='2011-10-1')

df.head()

plt.plot(df.Close)

moving_average(df)

# %%
# Dow Jones Index
tickerData = yf.Ticker('^DJI')

df = tickerData.history(period='1d', start='2010-1-1', end='2011-10-1')

df.head()

plt.plot(df.Close)

moving_average(df)

# %%
# NASDAQ
tickerData = yf.Ticker('^IXIC')

df = tickerData.history(period='1d', start='2005-1-1', end='2010-1-1')

df.head()

plt.plot(df.Close)

moving_average(df)

# %%
from statsmodels.tsa.stattools import adfuller
def test_stationarity(timeseries):
        
#Determing rolling statistics
    rol = timeseries
    rol['mean'] = df.Close.rolling(7).mean
    rol['std'] = timeseries.Close.rolling(7).std

    #Plot rolling statistics:
    orig = plt.plot(timeseries.Close, color='blue',label='Original')
    #mean = plt.plot(rol['mean'], color='red', label='Rolling Mean 7 day')
    #std = plt.plot(rol['std'], color='black', label = 'Rolling Mean 30 day')
    plt.legend(loc='best')
    plt.title('Rolling Mean & Standard Deviation')
    plt.show(block=False)
    
    #Perform Dickey-Fuller test:
    print('Results of Dickey-Fuller Test:')
    dftest = adfuller(timeseries, autolag='AIC')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    print(dfoutput)

# %%
test_stationarity(df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-46-850c081d31ba> in <module>
# ----> 1 test_stationarity(df)
#
# <ipython-input-45-0072bed8ba98> in test_stationarity(timeseries)
#      10     orig = plt.plot(timeseries.Close, color='blue',label='Original')
#      11     #mean = plt.plot(rol['mean'], color='red', label='Rolling Mean 7 day')
# ---> 12     std = plt.plot(rol['std'], color='black', label = 'Rolling Mean 30 day')
#      13     plt.legend(loc='best')
#      14     plt.title('Rolling Mean & Standard Deviation')
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2838 @_copy_docstring_and_deprecators(Axes.plot)
#    2839 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2840     return gca().plot(
#    2841         *args, scalex=scalex, scaley=scaley,
# ...
