# %%
import numpy as np
import pandas as pd
import pandas_datareader as pdr
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
gld = pdr.get_data_yahoo('GOOGL', '2016-11-08')
gld.head()
# Out:
#                   High         Low        Open       Close    Volume  \
# Date
# 2016-11-08  123.089996  121.360001  122.120003  121.639999   9480600
# 2016-11-09  124.349998  121.110001  124.300003  121.559998  18236500
# 2016-11-10  121.540001  119.379997  121.519997  119.750000  22268000
# 2016-11-11  119.690002  116.230003  119.650002  117.099998  20381800
# 2016-11-14  117.139999  115.489998  116.120003  116.110001  20729400
#
#              Adj Close
# Date
# 2016-11-08  121.639999
# 2016-11-09  121.559998
# 2016-11-10  119.750000
# 2016-11-11  117.099998
# 2016-11-14  116.110001

# %%
gld_close = pd.DataFrame(gld.Close)

# %%
gld_close['MA_9'] = gld_close.Close.rolling(9).mean()
gld_close['MA_21'] = gld_close.Close.rolling(21).mean()

# %%
plt.figure(figsize=(15,10))
plt.grid(True)
plt.plot(gld_close['Close'], label='GOOGL')
plt.plot(gld_close['MA_9'], label='MA 9 day')
plt.plot(gld_close['MA_21'], label='MA 21 day')
plt.legend(loc=2)

# %%
gld = pdr.get_data_yahoo('GOOGL', '2016-11-08')
gld.head()
# Out:
#                   High         Low        Open       Close   Volume  \
# Date
# 2016-11-08  816.039978  799.619995  802.030029  811.979980  1769100
# 2016-11-09  811.710022  792.039978  801.830017  805.590027  3098500
# 2016-11-10  810.059998  768.229980  810.000000  780.289978  5909600
# 2016-11-11  777.289978  765.539978  776.809998  771.750000  3592600
# 2016-11-14  771.780029  743.590027  771.760010  753.219971  3688300
#
#              Adj Close
# Date
# 2016-11-08  811.979980
# 2016-11-09  805.590027
# 2016-11-10  780.289978
# 2016-11-11  771.750000
# 2016-11-14  753.219971
